# %%
import pandas as pd 
import numpy as np

from sklearn.cluster import KMeans #pour kmeans
import seaborn as sns #pour scatterplots
import matplotlib.pyplot as plt

# %%
df_bechdel = pd.read_json("bechdel_data.json")

# %%
df_tmdb = pd.read_json("tmdb_data.json")

# %%
df_tmdb["imdbid"] = df_tmdb["imdb_id"].str[2:]

# %%
df = pd.merge(df_bechdel, df_tmdb, "left", "imdbid")

# %%
df
# Out:
#       year                   title_x   imdbid  id_x  rating  adult  \
# 0     1984                  C.H.U.D.  0087015  9327       2  False
# 1     1955    Les grandes manoeuvres  0048133  7878       3  False
# 2     1964        King &amp; Country  0058263  3250       0  False
# 3     2002          Coast Guard, The  0341384  3163       1  False
# 4     1965           Daikaiju Gamera  0059080  6428       2  False
# ...    ...                       ...      ...   ...     ...    ...
# 8479  1954                    Gojira  0047034  5505       1  False
# 8480  2005  Devil&#39;s Rejects, The  0395584  3628       3  False
# 8481  2008       Solo Quiero Caminar  1078600  7381       3  False
# 8482  2009        Le h&eacute;risson  1442519  2439       3  False
# 8483  1960      Les yeux sans visage  0053459   656       3  False
#
#                          backdrop_path  \
# 0     /zY9ahWKd9wVgQ6Rj5iL2zo0UvOt.jpg
# 1     /euSjkZqmCsONd8k5RMDLiGvxYhN.jpg
# 2     /wd7Hsv0jKGN8pmiM3WZ5SkB2nTu.jpg
# ...

# %%
df.columns
# Out:
# Index(['year', 'title_x', 'imdbid', 'id_x', 'rating', 'adult', 'backdrop_path',
#        'belongs_to_collection', 'budget', 'genres', 'homepage', 'id_y',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title_y', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df1=df[['rating','year']]
df1
#popularity 
#year 
#title_y
#imbid
#rating 
#genres
#overview
#original_language
#runtime
# Out:
#       rating  year
# 0          2  1984
# 1          3  1955
# 2          0  1964
# 3          1  2002
# 4          2  1965
# ...      ...   ...
# 8479       1  1954
# 8480       3  2005
# 8481       3  2008
# 8482       3  2009
# 8483       3  1960
#
# [8484 rows x 2 columns]

# %%
df1['vote_average'].max()
#10
# Out:
# 10.0

# %%
df['popularity'].max()
#10
# Out:
# 8542.716

# %%
df1.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# year      1995.891443
# rating       2.123173
# dtype: float64

# %%
df1[df1['original_title']=='The Lord of the Rings']
#attention aux mêmes noms
# Out:
#      year         original_title  \
# 173  1978  The Lord of the Rings
#
#                                               overview  rating
# 173  The Fellowship of the Ring embark on a journey...       1

# %%
df[df['original_language']=='en'].count()
# Out:
# year                     6508
# title_x                  6508
# imdbid                   6508
# id_x                     6508
# rating                   6508
# adult                    6508
# backdrop_path            6161
# belongs_to_collection    1300
# budget                   6508
# genres                   6508
# homepage                 6490
# id_y                     6508
# imdb_id                  6508
# original_language        6508
# original_title           6508
# overview                 6508
# popularity               6508
# poster_path              6443
# production_companies     6508
# production_countries     6508
# release_date             6508
# revenue                  6508
# runtime                  6505
# spoken_languages         6508
# status                   6508
# tagline                  6508
# title_y                  6508
# video                    6508
# vote_average             6508
# vote_count               6508
# dtype: int64

# %%
df[df['original_language']=='fr'].count()
# Out:
# year                     473
# title_x                  473
# imdbid                   473
# id_x                     473
# rating                   473
# adult                    473
# backdrop_path            435
# belongs_to_collection     41
# budget                   473
# genres                   473
# homepage                 472
# id_y                     473
# imdb_id                  473
# original_language        473
# original_title           473
# overview                 473
# popularity               473
# poster_path              465
# production_companies     473
# production_countries     473
# release_date             473
# revenue                  473
# runtime                  473
# spoken_languages         473
# status                   473
# tagline                  473
# title_y                  473
# video                    473
# vote_average             473
# vote_count               473
# dtype: int64

# %%
df[df['original_language']=='ja'].count()
# Out:
# year                     279
# title_x                  279
# imdbid                   279
# id_x                     279
# rating                   279
# adult                    279
# backdrop_path            269
# belongs_to_collection    111
# budget                   279
# genres                   279
# homepage                 279
# id_y                     279
# imdb_id                  279
# original_language        279
# original_title           279
# overview                 279
# popularity               279
# poster_path              279
# production_companies     279
# production_countries     279
# release_date             279
# revenue                  279
# runtime                  279
# spoken_languages         279
# status                   279
# tagline                  279
# title_y                  279
# video                    279
# vote_average             279
# vote_count               279
# dtype: int64

# %%
kmeans = KMeans(n_clusters=2, random_state=0).fit(df1)

# %%
df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   """Entry point for launching an IPython kernel.
# <style type="text/css">
# #T_da432_row0_col0, #T_da432_row1_col1, #T_da432_row2_col2, #T_da432_row3_col3, #T_da432_row4_col4, #T_da432_row5_col5, #T_da432_row6_col6, #T_da432_row7_col7, #T_da432_row8_col8, #T_da432_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_da432_row0_col1, #T_da432_row9_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_da432_row0_col2 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_da432_row0_col3 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_da432_row0_col4 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_da432_row0_col5, #T_da432_row2_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_da432_row0_col6 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# ...
